# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data.csv')

df = df[['mass Ax', 'mass Ay', 'mass B', 'mass By', 'mass Cx', 'mass Cy', 'mass Dx', 'mass Dy']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 df = pd.read_csv('Data.csv')
#       2
# ----> 3 df = df[['mass Ax', 'mass Ay', 'mass B', 'mass By', 'mass Cx', 'mass Cy', 'mass Dx', 'mass Dy']]
#
# File ~/.virtualenvs/Dynamics/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~/.virtualenvs/Dynamics/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...
